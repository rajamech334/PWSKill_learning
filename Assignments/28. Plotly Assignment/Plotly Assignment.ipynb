# %% [markdown]
# Q1. Load the "titanic" dataset using the load_dataset function of seaborn. Use Plotly express to plot a
# scatter plot for age and fare columns in the titanic dataset.

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#ans)
import seaborn as sns
import plotly.express as px

titanic_data = sns.load_dataset("titanic")
scatter_plot = px.scatter(titanic_data, x='age', y='fare', title='Scatter Plot of Age vs Fare')
scatter_plot.show()

# %% [markdown]
# Q2. Using the tips dataset in the Plotly library, plot a box plot using Plotly express.

# %%
#And)
import plotly.express as px

tips = px.data.tips()
box_plot = px.box(tips, x='day', y='total_bill', title='Box Plot of Total Bill by Day')
box_plot.show()

# %% [markdown]
# Q3. Using the tips dataset in the Plotly library, Plot a histogram for x= "sex" and y="total_bill" column in
# the tips dataset. Also, use the "smoker" column with the pattern_shape parameter and the "day"
# column with the color parameter

# %%
import plotly.express as px

tips = px.data.tips()
histogram = px.histogram(tips, 
                         x="sex", 
                         y="total_bill", 
                         color="day",
                         pattern_shape="smoker",
                         title="Histogram of Total Bill by Sex",
                         labels={"sex": "Sex", "total_bill": "Total Bill", "day": "Day", "smoker": "Smoker"},
                         opacity=0.7)

histogram.update_layout(barmode='overlay')
histogram.show()

# %% [markdown]
# Q4. Using the iris dataset in the Plotly library, Plot a scatter matrix plot, using the "species" column for
# the color parameter.

# %%
import plotly.express as px

iris = px.data.iris()
scatter_matrix = px.scatter_matrix(iris, 
                                   dimensions=["sepal_length", "sepal_width", "petal_length", "petal_width"], 
                                   color="species",
                                   title="Scatter Matrix Plot of Iris Dataset")
scatter_matrix.show()

# %% [markdown]
# Q5. What is Distplot? Using Plotly express, plot a distplot.
#
# Ans)
# A distplot, short for distribution plot, is a type of plot that displays the distribution of a univariate set of observations. It combines elements of histograms and kernel density estimation plots to provide a comprehensive view of the distribution of the data

# %%
import plotly.express as px

#Using tips data set for the plot
tips = px.data.tips()
distplot = px.histogram(tips, x="total_bill", marginal="box", opacity=0.7, histnorm="probability density")
distplot.show()
